# %%
import pandas as pd
from pandas.io.json import json_normalize
patients_df = pd.read_json('FlumeData.1592850823468.json', lines=True)
patients_df.head()
# Out:
#                                        quoted_status  \
# 0  {'in_reply_to_status_id_str': None, 'in_reply_...
# 1  {'extended_tweet': {'entities': {'urls': [], '...
# 2  {'extended_tweet': {'extended_entities': {'med...
# 3                                                NaN
# 4                                                NaN
#
#    in_reply_to_status_id_str  in_reply_to_status_id                created_at  \
# 0                        NaN                    NaN 2020-06-22 18:34:21+00:00
# 1                        NaN                    NaN 2020-06-22 18:34:21+00:00
# 2                        NaN                    NaN 2020-06-22 18:34:21+00:00
# 3                        NaN                    NaN 2020-06-22 18:34:21+00:00
# 4                        NaN                    NaN 2020-06-22 18:34:21+00:00
#
#    in_reply_to_user_id_str                                             source  \
# 0                      NaN  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
json_normalize(data)
